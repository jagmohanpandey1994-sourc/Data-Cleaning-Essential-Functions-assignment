# %% [markdown]
# 1. What is data cleaning, and why is it important in data analysis?
#  What are the potential consequences of analyzing unclean or messy data?
#  Explain the common steps involved in cleaning and organizing data.
#
#  <= It is the process of detecting and correcting inaccurate,duplicate from a dataset. it ensure that the data is accurate,consistent and ready to analysis.
#  It is important because clean data leads to more relible,accurate and meaningful analysis.
#  consequences of unclean or messy data-
#  > incorrect or biased analysis result
#  > misleading business decisions
#  > wasted time and resources
#  > reduced data quality and reliability
#  > Difficulty in creating predictive models
#  Comman steps in cleaning and organizing data
#  1.Data collection- verfiy that all required data has been collected correctly.
#  2.Handling Missing Values- Fill in,estimate or remove missing data points.
#  3.Removing Duplicates- identify and delete duplicate records.
#  4.Correcting Error- Fix typos,formatting mistakes and inconsistent entries.
#  5.Validating Data- Confirm that data values make useful for the analysis.
#  6.Organizing Data- Structure the cleaned data properly for analysis.
#
#  2.  How would you sort the following dataset first by "Department" (A-Z) and then by "Salary" (Largest to Smallest)? Write step-by-step approach.
#  Employee    Department    Salary
#  Sonu          IT            4000
#  Pranav        HR            5000
#  Rahul         IT            2500
#
#  <= Step1- department(a-z)
#  firstly apply fillter in employee,department, salary
#  and department in alphabetical order Hr comes before IT.
#  step2- within each department, sort by salary(largest- smallest)
#  >for HR only Parnav- no change
#  > For IT Sonu(4000) and Rahul(2500)-already in descending order.
#
#  3. Explain the use of text functions such as TRIM , LEFT, RIGHT, MID, and CONCAT in data cleaning.
#
#  <= 1.Trim- Remove spaces - standardizes text for comparison
#   2.LEFT - Extract from start -Get codes or prefixes
#   3.RIGHT -Extract from End -Get suffixes or Ids
#   4.MID - Extract from Middle -Isolate embedded data
#   5.CONCAT- Combine text -Merge separate fields
#
# 4. What is the role of date functions like TODAY in managing datasets?
#
# <= Data functions like TODAY() play an important role in managing and analyzing datasets,especially when working with data and time related information. the today() function automatically returns the current system data. it updates every day when the file is opened.
#
# 5. Apply Data Validation to restrict Quantity values to only whole numbers between 1 and 10.
# a. Configure an input message that appears when a user selects a cell in the "Quantity" column explaining:
#  "Please enter a whole number between 1 and 10."
# b. Set up an error alert message that triggers if the user enters a number less than 1 or greater than 10,
# showing:
#  "Invalid input! The quantity must be a whole number between 1 and 10."
# <= firstly select the quantity d2 to d10
# and go to excel ribbon and select- data - data tools- select data validation- select setting- Allow(select whole number), down side select mininum 1 and maximum 10 and ok.
# 2.Go to data validation again and select-input message- Please enter a whole number between 1 and 10 and ok.
# 3.again go to  data validation and Select-Error alert- in error box wite-The quantity must be a whole number between 1 and 10 and ok.
#
# 6. Understand and apply fundamental text functions like LEFT, RIGHT, MID, and LEN.
# . Extract the first 5 characters from the string "ExcelTipsAreGreat" using the LEFT function.
#  .Extract the last 4 characters from "DataAnalysis.xlsx" using the RIGHT function.
# . Extract the substring "Tips" from "ExcelTipsAreGreat" using the MID function.
# . Count the total number of characters in the string "Hello World!" using the LEN function.
# . Create a formula to extract the middle 6 characters from "12345-67890-ABCDE".
#
#  <=1.=LEFT("ExcelTipsAreGreat",5) -result(Excel)
#    2.=RIGHT("DataAnalysis.xlsx", 4) - result(xlsx)
#    3.=MID("ExcelTipsAreGreat", 6, 4)- result(Tips)
#    4.=LEN("Hello World!")- result(12)
#    5.=MID("12345-67890-ABCDE", 7, 6)- result(67890-)
#
# 7. Understand how to combine text using CONCAT, TEXTJOIN, and the & operator.
#  a.Use CONCAT to combine "Hello" and "World" with a space in between.
#  b.Combine "Apple", "Banana", and "Cherry" into a single string separated by commas using TEXTJOIN.
# c. Use the & operator to create the string "2025: Excel Functions" by combining "2025", ": ", and "Excel Functions".
#  d.Create a comma-separated list from the range A1:A5 using TEXTJOIN.
#  e.Combine first names in column A with last names in column B to create full names in column C.
#
#  <= a.=CONCAT("Hello", " ", "World") - result(Hello World)
#  b.=TEXTJOIN(",", TRUE, "Apple", "Banana", "Cherry")- result(Apple,banana,cherry)
#  c.="2025" & ": " & "Excel Functions" - result(2025:Excel Functions)
# d.=TEXTJOIN(",", TRUE, A1:A5)
# e. =A1 & " " & B1
#
# 8.  Understanding TODAY() and NOW()
#  a. What is the difference between TODAY() and NOW() in Excel? Provide an example of when you would use
#  each function.
#  b. If cell A1 contains the date 2025-06-10, write a formula using TODAY() to determine how many days are left until that date
#  c. Write an Excel formula using NOW() to display the current date and time in the format MM/DD/YYYY
#  HH:MM AM/PM. ́
#  d. If a cell contains =TODAY(), what will happen when the worksheet is reopened the next day? Explain
#  e. You want to store a static date (today’s date) in a cell without it changing every day. What keyboard shortcut should you use?
#
#  <=a. TODAY() - CURRENT date only
#     NOW() - current date & time
#
#     - Example for TODAY(): =TODAY() - result(2025-11-10)
#     - Example for NOW(): =NOW() → result(2025-11-10 10:53 PM)
# b. =A1 - TODAY() - result(Number of days remaining (updates daily))
# c. =TEXT(NOW(), "MM/DD/YYYY hh:mm AM/PM")
# d. When the worksheet is reopened the next day, =TODAY() automatically updates to reflect the new current date. It is dynamic and recalculates every time the sheet is refreshed or opened.
# e.Control key + semicolon
